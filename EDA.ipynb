# %% [markdown]
# [Data in Kaggle](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results?select=athlete_events.csv)

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # mount the data from Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Checking the Data carefully
# Loading the data, seeing its information, and having a statistical view of it.

# %%
df = pd.read_csv("/content/drive/MyDrive/athlete_events.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# #Data cleaning
# Turn all the strings characters in Dataframe to lowercase to avoid any duplicate data.

# %%
df = df.applymap(lambda x:x.lower() if type(x) == str else x)

# %% [markdown]
# Fix the Sex data in Dataframe, cause of there some players have multiple genders

# %%
names_with_def_sex=df.groupby('Name')['Sex'].apply(lambda x: np.NaN if x.unique().size == 1 else x.mode().max())
names_with_def_sex = names_with_def_sex.dropna()
names = names_with_def_sex.keys()
for name in names:
  df.loc[df["Name"]==name,"Sex"] = names_with_def_sex[name]

# %% [markdown]
# Filter all the numerical outlier data in the data frame using the IQR equation without dropping any NaN, cause I'm trying to estimate these Nan as well as possible.

# %%
df1 = df.groupby("Sport",as_index=True)

# %% [markdown]
# Find the IQR for every Sport ,cause of every sport has its ages and heights and weights...
#
# so i saw filtering outliers on all the sports together is a dumb idea.

# %%
sports = df["Sport"].unique()
filterd_df = pd.DataFrame(df.columns)
nan_df = pd.DataFrame(df.columns)
num_data = df1[["Sport","Age","Height",	"Weight"]]
Q1 = num_data.quantile(0.25)
Q3 = num_data.quantile(0.75)
IQR = Q3 - Q1
lower_pd = Q1 - 1.5 * IQR
upper_pd = Q3 + 1.5 * IQR

for sport in sports:
  df_grouped = df1.get_group(sport)
  mask = (df_grouped['Age'].between(lower_pd.loc[sport]["Age"], upper_pd.loc[sport]["Age"], inclusive="both") | df_grouped['Age'].isna())\
       & (df_grouped['Height'].between(lower_pd.loc[sport]["Height"], upper_pd.loc[sport]["Height"], inclusive="both") | df_grouped['Height'].isna())\
       & (df_grouped['Weight'].between(lower_pd.loc[sport]["Weight"], upper_pd.loc[sport]["Weight"], inclusive="both") | df_grouped['Weight'].isna())
      
  mask = mask[mask==False]
  filterd_sport_df = df[df["Sport"]==sport].drop(mask.index,inplace=False)
  

  if ~ pd.isna(filterd_sport_df['Height'].mean()):
    filterd_sport_df['Height'].fillna(value=np.round(filterd_sport_df['Height'].mean(),0),inplace=True)

  if ~ pd.isna(filterd_sport_df['Weight'].mean()):
    filterd_sport_df['Weight'].fillna(value=np.round(filterd_sport_df['Weight'].mean(),0),inplace=True)

  
  filterd_df = pd.concat([filterd_df, filterd_sport_df], axis=0)

df = filterd_df.dropna(thresh=5,axis=0)
df = df.drop(columns=[0])
display(df)
# Out:
#          Age       City                                         Event  \
# 0       24.0  barcelona                   basketball men's basketball
# 167     19.0    beijing                 basketball women's basketball
# 250     31.0   helsinki                   basketball men's basketball
# 264     29.0     sydney                   basketball men's basketball
# 346     25.0     munich                   basketball men's basketball
# ...      ...        ...                                           ...
# 230913  49.0   chamonix                       alpinism mixed alpinism
# 255672  47.0   chamonix                       alpinism mixed alpinism
# 50275   26.0      paris  basque pelota men's two-man teams with cesta
# 252988  26.0      paris  basque pelota men's two-man teams with cesta
# 214105  26.0     berlin                 aeronautics mixed aeronautics
#
#               Games  Height        ID Medal  NOC  \
# 0       1992 summer   180.0       1.0   NaN  chn
# 167     2008 summer   185.0      69.0   NaN  esp
# 250     1952 summer   191.0     124.0   NaN  egy
# 264     2000 summer   195.0     136.0   NaN  ita
# 346     1972 summer   189.0     192.0   NaN  egy
# ...             ...     ...       ...   ...  ...
# 230913  1924 winter     NaN  115888.0  gold  gbr
# 255672  1924 winter     NaN  128001.0  gold  gbr
# 50275   1900 summer     NaN   25866.0  gold  esp
# 252988  1900 summer     NaN  126675.0  gold  esp
# 214105  1936 summer     NaN  107506.0  gold  sui
#
#                                       Name  Season Sex          Sport  \
# 0                                a dijiang  summer   m     basketball
# 167                      tamara abalde daz  summer   f     basketball
# 250                  youssef mohamed abbas  summer   m     basketball
# 264                       alessandro abbio  summer   m     basketball
# 346     ahmed el-sayed abdel hamid mobarak  summer   m     basketball
# ...                                    ...     ...  ..            ...
# 230913          edward lisle "bill" strutt  winter   m       alpinism
# 255672            arthur william wakefield  winter   m       alpinism
# 50275               jos de amzola y aspiza  summer   m  basque pelota
# 252988        francisco villota y baquiola  summer   m  basque pelota
# 214105                   hermann schreiber  summer   m    aeronautics
#
#                  Team  Weight    Year
# 0               china    80.0  1992.0
# 167             spain    72.0  2008.0
# 250             egypt    85.0  1952.0
# 264             italy    85.0  2000.0
# 346             egypt    85.0  1972.0
# ...               ...     ...     ...
# 230913  great britain     NaN  1924.0
# 255672  great britain     NaN  1924.0
# 50275           spain     NaN  1900.0
# 252988          spain     NaN  1900.0
# 214105    switzerland     NaN  1936.0
#
# [264612 rows x 15 columns]

# %% [markdown]
# Create a nan_df that contains all rows with NaN value.

# %%
nan_df = pd.concat([df[df['Age'].isna()], df[df['Height'].isna()],df[df['Weight'].isna()]], axis=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 264612 entries, 0 to 214105
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Age     255155 non-null  float64
#  1   City    264612 non-null  object
#  2   Event   264612 non-null  object
#  3   Games   264612 non-null  object
#  4   Height  264514 non-null  float64
#  5   ID      264612 non-null  float64
#  6   Medal   38741 non-null   object
#  7   NOC     264612 non-null  object
#  8   Name    264612 non-null  object
#  9   Season  264612 non-null  object
#  10  Sex     264612 non-null  object
#  11  Sport   264612 non-null  object
#  12  Team    264612 non-null  object
#  13  Weight  264401 non-null  float64
#  14  Year    264612 non-null  float64
# dtypes: float64(5), object(10)
# memory usage: 32.3+ MB

# %%
nan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9766 entries, 2485 to 214105
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Age     254 non-null    float64
#  1   City    9766 non-null   object
#  2   Event   9766 non-null   object
#  3   Games   9766 non-null   object
#  4   Height  9545 non-null   float64
#  5   ID      9766 non-null   float64
#  6   Medal   957 non-null    object
#  7   NOC     9766 non-null   object
#  8   Name    9766 non-null   object
#  9   Season  9766 non-null   object
#  10  Sex     9766 non-null   object
#  11  Sport   9766 non-null   object
#  12  Team    9766 non-null   object
#  13  Weight  9427 non-null   float64
#  14  Year    9766 non-null   float64
# dtypes: float64(5), object(10)
# memory usage: 1.2+ MB

# %% [markdown]
# Fill NaN values in nan_df with the suitable values.

# %%
global player_names

# %%
player_names = nan_df.Name

# %%
meanbysex=df.groupby(["Sex"], as_index=False).mean()
meanbySport=df.groupby(["Sport"], as_index=True).Age.mean()
global favg_Height,mavg_Height,favg_Weight,mavg_Weight

favg_Height = meanbysex[meanbysex["Sex"]=="f"].Height
mavg_Height = meanbysex[meanbysex["Sex"]=="m"].Height
favg_Weight = meanbysex[meanbysex["Sex"]=="f"].Weight
mavg_Weight = meanbysex[meanbysex["Sex"]=="m"].Weight

# %%
names = player_names.unique()
def same_name(name,df):
  name_df = df[df["Name"] == name]
  name_Height = name_df[name_df["Height"].notna()]["Height"].mean()
  name_Weight = name_df[name_df["Weight"].notna()]["Weight"].mean()

  for i in range(name_df.Games.count()):
    if name_df.Games.count() == 1:
      name_df["Age"].fillna(value=np.round(meanbySport[name_df.iloc[0]["Sport"]],0),inplace=True)
    else:
      if  name_df.iloc[i]["Year"]==name_df["Year"].min():
        name_df.loc[name_df.index[i],"Age"] = np.round(meanbySport[name_df.iloc[0]["Sport"]],0)
      else:
        name_df.loc[name_df.index[i],"Age"] = np.round(meanbySport[name_df.iloc[0]["Sport"]],0) + name_df.iloc[i]["Year"] - name_df["Year"].min()

  if name_Height is np.NaN:
    name_df.loc[name_df["Sex"]=="f",'Height'] = np.round(favg_Height[0],0)
    name_df.loc[name_df["Sex"]=="m",'Height'] = np.round(mavg_Height[1],0)
  else: name_df['Height'].fillna(value=name_Height,inplace=True)
  
  if name_Weight is np.NaN:
    name_df.loc[name_df["Sex"]=="f",'Weight'] = np.round(favg_Weight[0],0)
    name_df.loc[name_df["Sex"]=="m",'Weight'] = np.round(mavg_Weight[1],0)
  else: name_df['Weight'].fillna(value=name_Weight,inplace=True)
  
  #display(name_df)
  return name_df

def nan_filler(names,df):
  flag = True
  i = 0
  for name in names:
    if flag:
      new_df = same_name(name,nan_df)
      flag=False
    else:
      new_df = pd.concat([new_df, same_name(name,nan_df)],ignore_index = True)
      print(name)
    i = i+1
    print(i)
  return new_df

new_df = nan_filler(names,nan_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Streaming output truncated to the last 5000 lines.
# giuseppe crivelli
# 3847
# carlos crosta noceti
# 3848
# ricardo santos da benta
# 3849
# delfim jos da silva
# 3850
# demetrios dais
# 3851
# douard dammann
# 3852
# bonifacio de bortoli
# 3853
# oscar de cock
# 3854
# gerard de gezelle
# 3855
# r. de landtsheere
# 3856
# sylvio augusto de souza e silva
# 3857
# lszl decker
# 3858
# antoine g. f. decours
# 3859
# henri delabarre
# 3860
# lon delignires
# 3861
# maurice delplanck
# 3862
# jules demar
# 3863
# victor denis
# 3864
# lon deslinires
# 3865
# alphonse dewette
# 3866
# robert d'heilly
# 3867
# adrien d'hondt
# 3868
# iakovidis diakoumakos
# 3869
# paulo diebold
# 3870
# stamatios diomataras
# 3871
# konstantinos ditsios
# 3872
# stepan dmitriyevsky
# 3873
# jos ribeiro do seixo
# 3874
# ioannis dolas
# 3875
# guillermo rafael douglas sabattini
# 3876
# thomas ian g. "tom" dowdall
# 3877
# duko orevi
# 3878
# aristidis drakakis
# 3879
# sveto drenovac
# 3880
# andreas drivas
# 3881
# richard duc
# 3882
# wilhelm "willy" dskow
# 3883
# paul chard
# 3884
# toshiji eda
# 3885
# rbert der
# 3886
# theodoros emeraldis
# 3887
# yoshio enomoto
# 3888
# alberto rafael errecalde
# 3889
# vasilios falangas
# 3890
# ioannis fasilis
# 3891
# pierre fauveau
# 3892
# pierre ferlin
# 3893
# amrico garcia fernandes
# 3894
# manuel fernndez
# 3895
# anatoly fetisov
# 3896
# nikolaos filippidis
# 3897
# nikolaos "nikos" filippidis
# 3898
# frdric fleig
# 3899
# robert fleig
# 3900
# ernesto flores filho
# 3901
# angelo fornaciari
# 3902
# nikolaos fotinakis
# 3903
# michel fourny
# 3904
# georgios fouskas
# 3905
# l. frediani
# 3906
# petros freskalakis
# 3907
# charles freuler
# 3908
# shigeo fujiwara
# 3909
# francisco augusto furtado
# 3910
# charles andr gaudin
# 3911
# abdallah gazi
# 3912
# ioannis georgas
# 3913
# jules georges
# 3914
# georgios georgitseas
# 3915
# ezio germignani
# 3916
# marius gervasoni
# 3917
# louis giobergia
# 3918
# john s. "jack" godwin
# 3919
# francesco gotti
# 3920
# ioannis gounaris
# 3921
# augusto graffigna
# 3922
# demetrios grous
# 3923
# ioannis grypaios
# 3924
# maurice gueissaz
# 3925
# robert guelpa
# 3926
# guilbert
# 3927
# ernst haas
# 3928
# stanley joe hanly
# 3929
# masao hara
# 3930
# saburo hara
# 3931
# lajos haraszthy
# 3932
# patrick d. r. "paddy" harold
# 3933
# taha hassouba
# 3934
# jozef hermans
# 3935
# yoshiki hiki
# 3936
# john grey hoben
# 3937
# jnos hollsi
# 3938
# maurice houdayer
# 3939
# andr houppelyne
# 3940
# kenzo ikeda
# 3941
# takashi imamura
# 3942
# kinichiro ishii
# 3943
# lzaro l. iturrieta
# 3944
# igor ivanov
# 3945
# pietro ivanov
# 3946
# harold r. ives
# 3947
# yozo iwasaki
# 3948
# josef jabor
# 3949
# douard jeandet
# 3950
# louis jeandet
# 3951
# william jones
# 3952
# j. jonlet
# 3953
# slobodan jovanovi
# 3954
# ioannis kaisarefs
# 3955
# demetrios kakousis
# 3956
# josef kala
# 3957
# bohdan kallmnzer
# 3958
# athanasios kalyvas
# 3959
# evangelos kanakaris
# 3960
# nikolaos karagiannis
# 3961
# pavlos karangonidis
# 3962
# nikolay karasyov
# 3963
# nikolaos karsouvas
# 3964
# vasilios katekhis
# 3965
# junichi kato
# 3966
# mikhail katsoulis
# 3967
# konstantinos kefalas
# 3968
# hans jakob keller
# 3969
# nikolaos khalas
# 3970
# evangelos khaldeos
# 3971
# argos khalykiopoulos
# 3972
# georgios khasapis
# 3973
# nikolaos "nikos" khatzigiakoumis
# 3974
# dionysios khristeas
# 3975
# zsigmond ern killer
# 3976
# vladimir aleksandrovich kirsanov
# 3977
# sndor kleckner
# 3978
# kroly koch
# 3979
# franz knig
# 3980
# a. kordonis
# 3981
# i. kottas
# 3982
# dimitrios kountouris
# 3983
# khristos koutoulangas
# 3984
# edmund kowalec
# 3985
# pavlos kypraios
# 3986
# ioannis lafiotis
# 3987
# athanasios lafis
# 3988
# charles lalemand
# 3989
# a. lambrecht, jr.
# 3990
# andr lancelot
# 3991
# lardon
# 3992
# l. le cornu
# 3993
# federico lecot
# 3994
# douard leguery
# 3995
# s. lemonis
# 3996
# robert lon
# 3997
# georges lonet
# 3998
# alfred lerbretier
# 3999
# khristos liambeis
# 4000
# durval bellini ferreira lima
# 4001
# enrique lingenfelder
# 4002
# lon lippens
# 4003
# p. lomvardos
# 4004
# spyridon "spyros" lomvardos
# 4005
# arthur f. long
# 4006
# walter loosli
# 4007
# guilherme lorena
# 4008
# ren lotti
# 4009
# ioannis loukas
# 4010
# r. macors
# 4011
# ibrahim mahmoud
# 4012
# maison
# 4013
# ivan makarov
# 4014
# anastasios maniatis
# 4015
# gaston maquat
# 4016
# sant marcuzzi
# 4017
# nikolaos mardelis
# 4018
# alphonse margailland
# 4019
# ilias marinos
# 4020
# georgios maroulis
# 4021
# lucien martinet
# 4022
# ren massiasse
# 4023
# charles massonnat
# 4024
# mathieu
# 4025
# setsuo matsura
# 4026
# maurice matthey
# 4027
# per alfred mattson
# 4028
# antonio mautrere
# 4029
# nikolaos mavrakis
# 4030
# dimitrios mavronas
# 4031
# william john "bill" mcconnell
# 4032
# brendan "barry" mcdonnell
# 4033
# edmund morgan aloysius mcelligott
# 4034
# ioannis melakhroinos
# 4035
# mario melchiori
# 4036
# h. mnard
# 4037
# achille meng
# 4038
# arrigo menicocci
# 4039
# f. mennella
# 4040
# s. messina
# 4041
# petros mexis
# 4042
# armin o. meyer
# 4043
# joseph meyer
# 4044
# h. micha
# 4045
# wacaw kazimierz michalski
# 4046
# isidoros mikhas
# 4047
# ioannis milakas
# 4048
# argos milonas
# 4049
# konstantinos misonginis
# 4050
# jos rodrgues m
# 4051
# oscar moreno
# 4052
# mario moretti
# 4053
# harry mos
# 4054
# jacques mottard
# 4055
# mikhail mouratis
# 4056
# jindich mula
# 4057
# wilhelm "willy" mller
# 4058
# jaroslav mysliveek
# 4059
# shokichi nanba
# 4060
# georgios nikolakis
# 4061
# georgios nikoloutsos
# 4062
# konstantinos niotis
# 4063
# taro nishidono
# 4064
# parmenios nomikos
# 4065
# alphonso nordio
# 4066
# kazuo nose
# 4067
# sreta novii
# 4068
# salvatore nuvoli
# 4069
# p. oddone
# 4070
# evangelos oikonomou
# 4071
# eusebio ojeda monje
# 4072
# jaroslav oplt
# 4073
# emil ordnung
# 4074
# andr pactat
# 4075
# konstantinos pagoulatos
# 4076
# donald robert "don" palmer
# 4077
# paoli
# 4078
# konstantinos papagiannoulis
# 4079
# n. papakostas
# 4080
# ioannis papapanagiotou
# 4081
# georgios papazis
# 4082
# filas paraskevaidis
# 4083
# emilios paravolos
# 4084
# orfeo paroli
# 4085
# demetrios pediadis
# 4086
# osrio antnio pereira
# 4087
# konstantinos perimenis
# 4088
# nikolaos petropoulos
# 4089
# n. petros
# 4090
# mile petrovi
# 4091
# peyronnie
# 4092
# demetrios piaditis
# 4093
# paul piaget
# 4094
# maxime piaggio
# 4095
# jean-paul pieddeloup
# 4096
# f. pieraccini
# 4097
# ioannis pilouris
# 4098
# antonios pitsilos
# 4099
# g. pizzo
# 4100
# mikhail andreyevich plaksin
# 4101
# angelo polledri
# 4102
# reginaldo polloni
# 4103
# yury popov
# 4104
# l. g. potter
# 4105
# louis prvel
# 4106
# alfred probst
# 4107
# federico probst
# 4108
# mikhail ivanovich prudnikov
# 4109
# theofilakos psiliakos
# 4110
# petros pterneas
# 4111
# orestes demstenes homero quintana y vigo
# 4112
# sebastiano randazzo
# 4113
# khristos rangos
# 4114
# leonel gonalves rgo
# 4115
# alois reinhard
# 4116
# maurice requill
# 4117
# n. retsinopoulos
# 4118
# charles harry rew
# 4119
# william c. "colonel" rice
# 4120
# maurice r. rieder
# 4121
# rezs riheczky
# 4122
# d. ringas
# 4123
# vladeta risti
# 4124
# walter "walt" robertson
# 4125
# paul a. robineau
# 4126
# louis roche
# 4127
# yury rogozov
# 4128
# marcel roman
# 4129
# carlos roque
# 4130
# e. rossi
# 4131
# enrico ruberti
# 4132
# vincenzo rubolotta
# 4133
# alberto ruggia
# 4134
# giuseppe russo
# 4135
# joseph a. "joe" ryan
# 4136
# mile sadzawska
# 4137
# menelaos sakorafos
# 4138
# carlos t. sambuceti
# 4139
# toshi sano
# 4140
# panagiotis saousopoulos
# 4141
# angelo sartini
# 4142
# hachiro sato
# 4143
# saurel
# 4144
# pierre sauvestre
# 4145
# josef schejbal
# 4146
# max w. schmid
# 4147
# josef schneider
# 4148
# hippolyte schouppe
# 4149
# fredy schultheiss
# 4150
# carlos semino
# 4151
# pietro sessa
# 4152
# aleksandr sheff
# 4153
# viktor shevchenko
# 4154
# umetaro shibata
# 4155
# eugen sigg (-bchthold)
# 4156
# jzsef sim
# 4157
# josef irc
# 4158
# vladimr irc
# 4159
# bogdan sirotanovi
# 4160
# romeo sisti
# 4161
# ren smet
# 4162
# mikhail sokos
# 4163
# tsukasa sonobe
# 4164
# demetrios souranis
# 4165
# aristidis spalieris
# 4166
# franz starkl
# 4167
# paul staub
# 4168
# anastasios stavrianos
# 4169
# alfred stefani
# 4170
# xenofon stellas
# 4171
# nikolaos stergiou
# 4172
# dominik tillip
# 4173
# vittore stocchi
# 4174
# sadahiro sunaga
# 4175
# lionel david "leonel" sutton
# 4176
# daikichi suzuki
# 4177
# oleg gennadyevich sveshnikov
# 4178
# jzef franciszek szawara
# 4179
# istvn szendeffy
# 4180
# rokuro takahashi
# 4181
# isamu takashima
# 4182
# yasuhiko takeda
# 4183
# robin w. r. tamplin
# 4184
# giovanni battista tanio
# 4185
# r. taormina
# 4186
# g. tarantino
# 4187
# albert "al" taylor
# 4188
# david daniel b. "danny" taylor
# 4189
# livio tesconi
# 4190
# franois thonin
# 4191
# p. toio
# 4192
# henrique tomassini
# 4193
# carlo toniatti
# 4194
# antnio gonalves torres
# 4195
# enrique torres larrauri
# 4196
# armando trabucco
# 4197
# yevgeny tretnikov
# 4198
# georgios tsakonas
# 4199
# ioannis tsirakis
# 4200
# khristos tsirigotakis
# 4201
# 4310
# gaston achille
# 4311
# charles acke
# 4312
# johannes "johann" adam
# 4313
# elie adda
# 4314
# albino manuel agero
# 4315
# antonio ahumada ruiz
# 4316
# ahmed abdulrahman al-arbeed
# 4317
# nassar ali al-dosari
# 4318
# ahmed al-doseri
# 4319
# nahedh al-murdh
# 4320
# khaled fahd al-rasheed
# 4321
# rashid fahd al-rasheed
# 4322
# edoardo alaimo
# 4323
# gordon reuben alexander
# 4324
# eduardo h. alonso
# 4325
# georgios ambet
# 4326
# jamal hussayn ameen
# 4327
# andreac
# 4328
# emmanuel andrieu
# 4329
# mikhail anerrapsis
# 4330
# s. antonidas
# 4331
# jen apthy
# 4332
# valentino vittorio argento
# 4333
# boris nikolayevich arsenyev
# 4334
# rza arseven
# 4335
# jean-gabriel asfar
# 4336
# ass
# 4337
# aufort
# 4338
# richard a. badman
# 4339
# vural balcan
# 4340
# nihat balkan
# 4341
# jorge balza
# 4342
# mile edmond gustave barbier
# 4343
# bazin
# 4344
# g. bllot
# 4345
# hctor belo herrera
# 4346
# boris ivanovich belyakov
# 4347
# konstantinos bembis
# 4348
# giovanni benfratello
# 4349
# rudolf berger
# 4350
# charles bersin
# 4351
# gavriil bertrain
# 4352
# miroslav beznoska
# 4353
# raoul bzy-bideau
# 4354
# raoul bideau
# 4355
# gabriel blando
# 4356
# francisco c. bollini
# 4357
# aldo boni
# 4358
# suzanne bonnard
# 4359
# bormel
# 4360
# marcelle bory
# 4361
# mile bouard
# 4362
# marcel boulanger
# 4363
# jean a. boulge
# 4364
# josiah frederick dollin bowden
# 4365
# j. brassard
# 4366
# brau
# 4367
# rudolf brosch
# 4368
# richard brnner
# 4369
# raymond neville "ray" buckingham
# 4370
# maude margaret "peggy" butler
# 4371
# harry robert butterworth
# 4372
# giulio cagiati
# 4373
# albert simon cahen
# 4374
# calvet
# 4375
# camier
# 4376
# juan roberto camous
# 4377
# cannesson
# 4378
# gheorghe caranfil
# 4379
# dante carniel
# 4380
# horacio casco parejas
# 4381
# abelardo castro ramrez
# 4382
# cr
# 4383
# jan ernohorsk
# 4384
# manuel pereira chagas
# 4385
# anthony p. chalke
# 4386
# jarmila chalupov
# 4387
# louis mile chapuis
# 4388
# mohamed mustafa charaoui
# 4389
# georges marie clappier
# 4390
# raoul clry
# 4391
# constant robert cloquet
# 4392
# renzo compagna
# 4393
# georges joseph conraux
# 4394
# yvonne conte
# 4395
# henri jules coquelin
# 4396
# fernando correia
# 4397
# costiesco
# 4398
# louis gaston coudurier
# 4399
# thomas george "tom" cross
# 4400
# luigi cuomo
# 4401
# georges dambois
# 4402
# dambremat
# 4403
# marie-louis damotte
# 4404
# gladys daniell
# 4405
# cyrus leaf daniell
# 4406
# henry d. davids
# 4407
# geraldo "gil" de andrade
# 4408
# jean alexandre de bardel
# 4409
# franois de boffa
# 4410
# de cazeneuve
# 4411
# de la chevalerie
# 4412
# henri de laborde
# 4413
# de lagardire
# 4414
# de lastic
# 4415
# de meuse
# 4416
# de pradines
# 4417
# a. de romigny
# 4418
# de saint-aignan
# 4419
# de segonzac
# 4420
# de tournable
# 4421
# louis de tribolet
# 4422
# de vars
# 4423
# debrinay
# 4424
# henri jean dbut
# 4425
# delprat
# 4426
# eugne des logis berges
# 4427
# desprs
# 4428
# f. desprs
# 4429
# hilda deswarte
# 4430
# ugo di nola
# 4431
# dino diana
# 4432
# dizier
# 4433
# harry dombeeck
# 4434
# jean dreyfus
# 4435
# david d. drury
# 4436
# andr du bosch
# 4437
# duclot
# 4438
# ducreuil
# 4439
# mile r. dufranc
# 4440
# constant dulau
# 4441
# frantiek duek
# 4442
# gaston jean dutertre
# 4443
# frantiek dvok
# 4444
# mrton endrdi
# 4445
# partick james "pat" farrell
# 4446
# giunio fedreghini
# 4447
# spyridon ferentinos
# 4448
# fernands
# 4449
# ferrand
# 4450
# santos a. ferreira
# 4451
# fichot
# 4452
# pavel filatov
# 4453
# theodor fischer
# 4454
# flahaut
# 4455
# maurice fleury
# 4456
# joseph fontaine
# 4457
# konstantinos fotiadis
# 4458
# douard pascal fouchier
# 4459
# theodoros foustanos
# 4460
# stan franois
# 4461
# robert frater
# 4462
# uro frojnd (freund)
# 4463
# franjo frelih (frhlich)
# 4464
# nlida fullone
# 4465
# marie-joseph gabriel
# 4466
# carlo gandini
# 4467
# santiago garca canudas
# 4468
# gardis
# 4469
# louis garnoty
# 4470
# jorge garretn prieto
# 4471
# albert gauthier
# 4472
# louis gauthier
# 4473
# daniel "dan" gheorghiu
# 4474
# giuseppe giurato
# 4475
# julio a. gonzlez boada
# 4476
# nikolay goredetsky
# 4477
# e. grad
# 4478
# arthur dillon griez von ronse
# 4479
# leonid vladimirovich grinyov
# 4480
# grossard
# 4481
# charles gurin
# 4482
# alexandre guillemand
# 4483
# fernando guilln iglesias
# 4484
# pavel guvorsky
# 4485
# majed abdul rahim habib ullah
# 4486
# vera hagemann
# 4487
# elizabeth "betty" hamilton
# 4488
# william hammond
# 4489
# antal hmos
# 4490
# hassan hamze
# 4491
# martin g. harden
# 4492
# laurence neville harding-smith
# 4493
# harstein
# 4494
# hbrant
# 4495
# hrisson
# 4496
# luis hernndez
# 4497
# hugo higueras ureta
# 4498
# jean-andr hilleret
# 4499
# hug hoch
# 4500
# lajos horvth
# 4501
# ernst huber
# 4502
# georgios iatridis
# 4503
# carlos iturri quevedo
# 4504
# yury ivanov
# 4505
# ivan ivanovitch
# 4506
# raymundo izcoa
# 4507
# henri jacquet
# 4508
# jactel
# 4509
# jack evan james
# 4510
# maximilien gustave berthold marie "max" janlet
# 4511
# maurice joseph jay
# 4512
# luis jimnez pea
# 4513
# jolliet
# 4514
# lois margaret joseph (-green)
# 4515
# ayman jumean
# 4516
# gaston kaanen
# 4517
# gusztv (gyula) klniczky
# 4518
# panagiotis a. kambas
# 4519
# tilemakhos karakalos
# 4520
# ioannis karamazakis
# 4521
# alfred valentine keene
# 4522
# jacques kesteloot
# 4523
# vladimir keyser
# 4524
# alexandros kharalambopoulos
# 4525
# nikolaos khristogiannopoulos
# 4526
# milo klika
# 4527
# anita klpfel
# 4528
# konstantinos komninos-miliotis
# 4529
# triantafyllos kordogiannis
# 4530
# aristidis kritikos
# 4531
# va kun
# 4532
# nikolay kuznetsov
# 4533
# ludovic laborderie
# 4534
# a. lafontaine
# 4535
# jean lafoucrire
# 4536
# jean-baptiste lafourade-cortina
# 4537
# jules large
# 4538
# larivire
# 4539
# ren lateux
# 4540
# launay
# 4541
# pierre le blon
# 4542
# philippe le hardy de beaulieu
# 4543
# georges lefvre
# 4544
# adjutant lemoine
# 4545
# feliks zenovich leparsky
# 4546
# paul leroy
# 4547
# georges lvcque
# 4548
# marcel lvy
# 4549
# lzard
# 4550
# elena libera
# 4551
# jos llauro
# 4552
# alfonso mario lpez
# 4553
# fidel lua herrera
# 4554
# luquetas
# 4555
# jules germain marie maes
# 4556
# olive mahaut
# 4557
# lylian malherbaud-lecomte-guyonneau
# 4558
# firidun malkom khan
# 4559
# ramro maalich
# 4560
# nikolaos manolesos
# 4561
# joseph cyrille marais
# 4562
# robert marc
# 4563
# martini
# 4564
# leonid martuchev
# 4565
# mass
# 4566
# graham philip mckenzie
# 4567
# walther meienreis
# 4568
# domingo r. mendy
# 4569
# pedro h. mendy
# 4570
# pedro mercado
# 4571
# joseph-auguste mtais
# 4572
# yulian aleksandrovich michaux
# 4573
# jean michel
# 4574
# louis midelair
# 4575
# antonn mikala
# 4576
# bla mikla
# 4577
# jean mikorski
# 4578
# miller
# 4579
# lucien millet
# 4580
# osvaldo miranda garbancho
# 4581
# joseph misrahi
# 4582
# cyril mohr
# 4583
# ernst moldenhauer
# 4584
# lopold l. montagnier
# 4585
# marcel montuel
# 4586
# alphonse moquet
# 4587
# louis moreau
# 4588
# moreil
# 4589
# jeanne morgenthaler (-mende)
# 4590
# achille morin
# 4591
# mosso
# 4592
# saul moyal
# 4593
# muller
# 4594
# arthur c. murray
# 4595
# bla nagy
# 4596
# athanasios nanopoulos
# 4597
# boris gavrilovich nepokupnoy
# 4598
# hassan niazi
# 4599
# konstantinos "kostas" nikolopoulos
# 4600
# oscar novoa fuentes
# 4601
# muhuttin okyavuz
# 4602
# ludk oppl
# 4603
# paul antoine oziol de pignol
# 4604
# pl pajzs
# 4605
# palardi
# 4606
# aristidis papadakis
# 4607
# nikolaos paparrodou
# 4608
# charles pape
# 4609
# jacques parent
# 4610
# passerat
# 4611
# pboray
# 4612
# pierre pcher
# 4613
# plabon
# 4614
# rzvan penescu
# 4615
# raphal perrissoud
# 4616
# karl august petri
# 4617
# josef pfeiffer
# 4618
# hugo philipp
# 4619
# periklis pierrakos-mavromikhalis
# 4620
# pitory
# 4621
# francesco pietrasanta
# 4622
# aroldo n. s. luigi pinelli
# 4623
# piot
# 4624
# appolinariya mykolavna plekhanova
# 4625
# eugne plisson
# 4626
# arturo ponce costa
# 4627
# aristide pontenani
# 4628
# ioannis poulos
# 4629
# preurot
# 4630
# prosper
# 4631
# lucienne prost
# 4632
# menelaos psarrakis
# 4633
# leonidas "leon" pyrgos
# 4634
# manuel queirz
# alfred louis badu
# 4744
# joo eduardo gamarro correia barrento
# 4745
# armando barriguete
# 4746
# kevin barry
# 4747
# marcel blanchard
# 4748
# bedri bke
# 4749
# alain pierre marie bouchet
# 4750
# antoine boudet
# 4751
# jean-albert brasu
# 4752
# oldich buchar
# 4753
# marcos "marc" bchler
# 4754
# gavriil budyonny
# 4755
# cabanac
# 4756
# selim akir
# 4757
# georges jean andr calmon
# 4758
# eduardo w. cano
# 4759
# cauchy
# 4760
# eugenio cerboneschi
# 4761
# bertrand chanu
# 4762
# cordon
# 4763
# gustave jacques couderc de fonlongue
# 4764
# paul covert
# 4765
# jacques d'arlincourt
# 4766
# de coulombier
# 4767
# de lamaratine
# 4768
# lie de polyakov
# 4769
# de prunel
# 4770
# paul de saint-lger
# 4771
# alvaro luciano dias de toledo
# 4772
# georges de zogheb
# 4773
# enrique deichler miranda
# 4774
# amabrio simn del villar
# 4775
# frantiek donda
# 4776
# omar ahmed el-hadary
# 4777
# ren c. emanuelli
# 4778
# jean esnault-pelterie
# 4779
# vctor fernndez bazn
# 4780
# field
# 4781
# formal i
# 4782
# formal ii
# 4783
# francesco fourquet
# 4784
# oskar frank
# 4785
# elwi gazi
# 4786
# willy gerber
# 4787
# emil-otto "milo" gmr
# 4788
# oscar goul
# 4789
# elvira guerra
# 4790
# alpaslan gne
# 4791
# fethi grcan
# 4792
# maurice jhin
# 4793
# bedich john
# 4794
# kudret kasar
# 4795
# mohamed khairy
# 4796
# patrick joseph kiernan
# 4797
# jacques la caze
# 4798
# jean le vavasseur
# 4799
# henri leclerc
# 4800
# john a. "jack" lewis
# 4801
# hermann john mandl
# 4802
# nicolae marcoci
# 4803
# carlos helario mejia
# 4804
# juan martn merbilha
# 4805
# nicolae mihalcea
# 4806
# min byeong-seon
# 4807
# giuseppe molinari
# 4808
# eugenio monterosso
# 4809
# moulin
# 4810
# eyp nc
# 4811
# orban
# 4812
# procopio ortz reyes
# 4813
# jos prez allende
# 4814
# phillippot
# 4815
# mikhail mikhaylovich pleshkov
# 4816
# henri plocque
# 4817
# georges pierre joseph poff
# 4818
# josef rabas
# 4819
# francisco r. reyes carrere
# 4820
# lon hippolyte rigon
# 4821
# roy
# 4822
# jos mara sagasta
# 4823
# salins
# 4824
# vctor manuel saucedo carillo
# 4825
# aleksey nikolayevich selikhov
# 4826
# antnio de jesus serdio
# 4827
# gheorghe soare
# 4828
# humberto l. m. terzano
# 4829
# lon thome
# 4830
# vasily nikolayevich tikhonov
# 4831
# ruggero "roger" ubertalli
# 4832
# leone valle
# 4833
# van der meulen
# 4834
# georges van der poele
# 4835
# van ranst
# 4836
# van schauwenbroeck
# 4837
# philippe vernes
# 4838
# andr vidart
# 4839
# vigneulles
# 4840
# roberto c. vials contreras
# 4841
# mikhail vlasov
# 4842
# aleksandr vtorov
# 4843
# elias yez
# 4844
# eyp yiittrk
# 4845
# mohamed ghulom abdul rahman
# 4846
# eugene addor
# 4847
# ador
# 4848
# safaq qaed al-anzi
# 4849
# sayed mohamed al-asibi
# 4955
# miguel emmanuelli
# 4956
# ren englebert
# 4957
# pelegrn esteve magnet
# 4958
# evangelos evangelidis
# 4959
# ulrich fahrner
# 4960
# youssef fares
# 4961
# luigi favretti
# 4962
# eid almas mubarak fayroze
# 4963
# edouard feisinger
# 4964
# dionisio e. fernndez
# 4965
# antnio soares de andra ferreira
# 4966
# jos maria soares de andra ferreira
# 4967
# alexios fetsis
# 4968
# claudio fiorentini
# 4969
# mylie e. fletcher
# 4970
# rodolfo flores garca
# 4971
# rigoberto fontt
# 4972
# alfr. fotiadis
# 4973
# jean fouconnier
# 4974
# ioannis frangoudis
# 4975
# bruno frank
# 4976
# raffaele frasca
# 4977
# james c. freeborn
# 4978
# vasily frolov
# 4979
# georgios gaitanos
# 4980
# alfredo galli
# 4981
# r. gauthier-lafond
# 4982
# joseph geens
# 4983
# platon georgitsis
# 4984
# douard geynet
# 4985
# vasile ghiescu
# 4986
# peter h. griffiths
# 4987
# ricardo grimau
# 4988
# federico grben
# 4989
# carlos guerrero martnez
# 4990
# n. guyot
# 4991
# ren guyot
# 4992
# eliazar guzmn
# 4993
# joseph haesaerts
# 4994
# j. haller
# 4995
# enrique hannaberg
# 4996
# tanios harb
# 4997
# robert hawkins
# 4998
# spiro hayek
# 4999
# arnulfo hernndez
# 5000
# teodoro hernndez
# 5001
# d. hesse
# 5002
# franois heyens
# 5003
# hilaret
# 5004
# william hill
# 5005
# khalil amin hilmi
# 5006
# heinrich hintermann
# 5007
# ricardo hizon
# 5008
# miloslav hlav
# 5009
# franz hollitzer
# 5010
# josef hosa
# 5011
# hng hong thi
# 5012
# richard hutton
# 5013
# csar jorge injoque hurst
# 5014
# ivan isayev
# 5015
# camillo isnardi
# 5016
# ernest ista
# 5017
# alexander townsend jackson
# 5018
# joseph janssens
# 5019
# abdullah jaroudi, sr.
# 5020
# charles james jeffers
# 5021
# joseph jehle
# 5022
# antonn jlek
# 5023
# fernando jimnez
# 5024
# george a. j. jones
# 5025
# james m. jones
# 5026
# lazar jovanovi
# 5027
# g. karagiannopoulos
# 5028
# karakatsanis
# 5029
# pantelis karasevdas
# 5030
# anastasios karatzas
# 5031
# khatzidakis
# 5032
# evangelos "vangelis" khrysafis
# 5033
# kim yong-bae
# 5034
# kim yun-gi
# 5035
# vclav kindl
# 5036
# richard klier
# 5037
# georgios kontogiannis
# 5038
# ioannis koutsis
# 5039
# josef kozlk
# 5040
# aristidis kronis
# 5041
# josef kruz
# 5042
# marcel lafitte
# 5043
# abdesselem lahmidi
# 5044
# leslie laing
# 5045
# leonidas lanngakis
# 5046
# giuseppe laveni
# 5047
# james n. le fevre
# 5048
# gaston legrand
# 5049
# s. lesceux
# 5050
# david e. lewis
# 5051
# vincent libert
# 5052
# liew foh sin
# 5053
# panagiotis linardakis
# 5054
# josef linert
# 5055
# george seath lishman
# 5056
# cesare liverziani
# 5057
# konstantinos loudaros
# 5058
# enrique lucca escobar
# 5059
# salvatore lucchesi
# 5060
# jos macedo
# 5061
# pavel mach
# 5062
# machonet
# 5173
# georgios skotadis
# 5174
# fernando soledade
# 5175
# manuel de j. solis
# 5176
# vasily sorokin
# 5177
# soucaret
# 5178
# dimitrios spiliotopoulos
# 5179
# spyridon stais
# 5180
# em. vasileios stais
# 5181
# dimitrios stathis
# 5182
# georgios stathis
# 5183
# j. arthur steele
# 5184
# r. stphan
# 5185
# john stiray
# 5186
# josef tojdl
# 5187
# conrad stucheli
# 5188
# g. sylva
# 5189
# elemr takcs
# 5190
# froiln tantalen zorilla
# 5191
# abdel sattar tarabulsi
# 5192
# albert e. taylor
# 5193
# constantin enescu
# 5194
# lon e. ttart
# 5195
# konstantinos thanopoulos
# 5196
# parvati thapa
# 5197
# alexandros theofilakis
# 5198
# ioannis theofilakis
# 5199
# mile thves
# 5200
# jacques thuriaux
# 5201
# ricardo ticchi
# 5202
# james richard trembath
# 5203
# matthias triantafyllidis
# 5204
# nikolaos trikoupis
# 5205
# troffaes
# 5206
# nikolaos tzovlas
# 5207
# georgios vafeiadis
# 5208
# ilias valatas
# 5209
# ludovic valborge
# 5210
# federico valle
# 5211
# norbert van molle
# 5212
# alexandru vatamanu
# 5213
# vavis
# 5214
# l. vignola
# 5215
# andreas vikhos
# 5216
# arturo villanueva
# 5217
# alois sigfrido vogel
# 5218
# albert von einsiedel
# 5219
# ioannis vourakis
# 5220
# konstantinos voutieridis
# 5221
# alexandros vrasivanopoulos
# 5222
# james "jack" warner
# 5223
# weibel
# 5224
# emil werner
# 5225
# percy kay whitehead
# 5226
# arthur william wilde
# 5227
# bruce m. williams
# 5228
# vasileios xylinakis
# 5229
# samad molla zal
# 5230
# robert zedwane
# 5231
# bouchaib zeroual
# 5232
# georgios zisimos
# 5233
# erich zoigner
# 5234
# mohamed jamshid abadi
# 5235
# mohamed abakkar
# 5236
# hwad ibrahim abdel hamid lumomba
# 5237
# abdel wahab abdullah salih
# 5238
# edward adams
# 5239
# frederick thomas "fred" adams
# 5240
# alberto adela
# 5241
# ricardo adolfo
# 5242
# gharib afifi
# 5243
# alego akomi
# 5244
# mohamed al moukdad
# 5245
# abdullah salim al-barwani
# 5246
# handhal mohamed al-harithy
# 5247
# charles albert
# 5248
# efstathios alexopoulos
# 5249
# mohamed ammi
# 5250
# chibou amna
# 5251
# michael andrews
# 5252
# jules androt
# 5253
# peter anok kabeni
# 5254
# miguel araico lvarez
# 5255
# william robert "billy" barber
# 5256
# william e. "billy" barnes
# 5257
# joseph j. "johnny" basham
# 5258
# robert "bobby" bath
# 5259
# arthur henry beavis
# 5260
# richard "dick" beland
# 5261
# abdel kader belghiti
# 5262
# fatah ben farj
# 5263
# moustafa ben lahbib
# 5264
# lszl bene
# 5265
# damber dutta bhatta
# 5266
# rabindranath "rabin" bhatta
# 5267
# victor bignon guzman
# 5268
# lucien biquet
# 5269
# clyde cecil bissett
# 5270
# georges boireau
# 5271
# james bollinger
# 5272
# ahmed bouazza
# 5273
# mohamed boubekeur
# 5274
# mohamed bouchara
# 5275
# alberto luis boullossa dobal
# 5276
# andr bouvier
# 5384
# louis a. lavoie
# 5385
# patrick joseph lenehan
# 5386
# william "willie" lenihan
# 5387
# vichai limcharoen
# 5388
# john lloyd
# 5389
# anthony longdon
# 5390
# manuel lpez
# 5391
# bla lwig
# 5392
# john "jock" macgregor
# 5393
# chand c. machiah
# 5394
# teddy makofi
# 5395
# djingarey mamoudou
# 5396
# anthony "tony" mancini
# 5397
# ganapathy manoharan
# 5398
# kasamiro kashri marchlo
# 5399
# augustino marial
# 5400
# umesh maskey
# 5401
# leslie thomas "les" mason
# 5402
# antoine masson
# 5403
# nikolaos mastoridis
# 5404
# maung myo thant
# 5405
# charles mayer
# 5406
# pierre mazior
# 5407
# michael "myles" mcdonagh
# 5408
# james "jim" mcgregor
# 5409
# michael "mick" mckeon
# 5410
# paulino melndres
# 5411
# abraham mieses
# 5412
# ernest mignard
# 5413
# dimitrios mikhail
# 5414
# john michel mirona
# 5415
# al-mahjoub m'jirih
# 5416
# neva mkadala
# 5417
# kornel molnr
# 5418
# jorge monard
# 5419
# allan monteiro
# 5420
# charles morard
# 5421
# charles w. "charley" morris
# 5422
# phajol muangson
# 5423
# hans mller
# 5424
# timsah okalo mulwal
# 5425
# agustn g. muiz sellanes
# 5426
# juan muoz panades
# 5427
# arthur murdoch
# 5428
# james j. "jim" murphy
# 5429
# david mwaba
# 5430
# moses mwaba
# 5431
# christopher mwamba
# 5432
# webbyego mwangu
# 5433
# keith mwila
# 5434
# ian myrams
# 5435
# ezz el-din nasir
# 5436
# edward neblett
# 5437
# jean neyes
# 5438
# paul nicolas
# 5439
# john o. h. nuttall
# 5440
# r. nyffeler
# 5441
# alexander indrajith "alex" obeysekera (obeysekere)
# 5442
# gearid "gerry"  colmin
# 5443
# hugh o'hagan
# 5444
# patrick philip o'hanrahan (zoller-)
# 5445
# george cornelius "con" o'kelly, jr.
# 5446
# carlos orellana
# 5447
# william o'shea
# 5448
# frank osborne
# 5449
# badie ovnteni
# 5450
# arnoldo pars
# 5451
# chune pattapong
# 5452
# tobi pelly obanio
# 5453
# albert perera
# 5454
# henry perry
# 5455
# alois petina
# 5456
# tienne poillot
# 5457
# manuel ponce
# 5458
# tom ptsch
# 5459
# miloslav phoda
# 5460
# georges arthur "art" prud'homme
# 5461
# om prasad pun
# 5462
# otakar rademacher
# 5463
# masoud rahimiha
# 5464
# sen k. rai
# 5465
# dalbahadur ranamagar
# 5466
# ahmed rashid
# 5467
# ghasem rassaeli
# 5468
# gul rehmat
# 5469
# willy reichenbach
# 5470
# carlos reyes
# 5471
# henri ricard
# 5472
# henri martin richards
# 5473
# thomas "tom" ringer
# 5474
# salvador rivera senz
# 5475
# mirgaani gomaa rizgalla
# 5476
# angel rodrguez
# 5477
# jos arturo rubio fernndez
# 5478
# lincoln salcedo reina
# 5479
# anicet sambo
# 5480
# marcel sartos
# 5481
# jacques sauthier
# 5482
# louis sauthier
# 5483
# hardy saw
# 5484
# ernst "edy" schmidiger
# 5485
# hermann schneider
# 5486
# hans schwerzmann
# 5487
# mayaki seydou
# 5701
# khem son
# 5702
# kim ho-sun
# 5703
# jack king
# 5704
# mikhail klaynerov
# 5705
# martin klb
# 5706
# milo knobloch
# 5707
# anatoly ivanovich kolesov
# 5708
# georgios koletis
# 5709
# aristidis konstantinidis
# 5710
# konstantinos konstantinou
# 5711
# josip kosmatin
# 5712
# evangelos "vangelis" kouvelis
# 5713
# max kricheldorf
# 5714
# vladimir kryuchkov
# 5715
# otto kpferling
# 5716
# mohamed gandoura lacheb
# 5717
# khristos lagos
# 5718
# abdallah lahoucine
# 5719
# andr lapize
# 5720
# manuel largaespada flores
# 5721
# leonard "leo" larson
# 5722
# lajos lt
# 5723
# joseph l. "joe" lavery
# 5724
# samuel "sam" lavoice
# 5725
# l'empereur
# 5726
# henry h. lee
# 5727
# paul legrain
# 5728
# petros leonidis
# 5729
# theodor ferdinand leupolt
# 5730
# ernst leutert
# 5731
# l. f. "laddie" lewis
# 5732
# felipe lian saldaa
# 5733
# lohner
# 5734
# longchamp
# 5735
# jos h. lpez
# 5736
# luis lpez
# 5737
# loverdos
# 5738
# william lower
# 5739
# jorge alfonso luque ballon
# 5740
# jean madelaine
# 5741
# mohamed madkour
# 5742
# w. f. "willie" magee
# 5743
# mohamed ali aly mahmoud
# 5744
# maibaum
# 5745
# eduardo maillard crampes
# 5746
# joseph mallet
# 5747
# antonio malvassi
# 5748
# mile marchal
# 5749
# alfred "fred" markus
# 5750
# fernando marroqun
# 5751
# charles marshall
# 5752
# harry percy martin
# 5753
# pietro martinelli
# 5754
# nikolaos mavrogenis
# 5755
# herbert "herb" mcdonald
# 5756
# cecil mckaig
# 5757
# otto meixner
# 5758
# len ngel meja
# 5759
# henri menjou
# 5760
# louis mermillod
# 5761
# viktor meshkov
# 5762
# douard meunier
# 5763
# ernst meyer
# 5764
# oswald miller (mller)
# 5765
# eruch mistry
# 5766
# volodymyr oleksandrovich mitin
# 5767
# issa mohamed
# 5768
# enrique molina
# 5769
# maurice monniot
# 5770
# hctor monsalve castaeda
# 5771
# frank montaldi
# 5772
# roy thomas moore
# 5773
# gustave moos
# 5774
# rajab walaan moqbil
# 5775
# mossmann
# 5776
# faustin mparabanyi
# 5777
# muharud mukasa
# 5778
# rustom "rusi" mulla feroze
# 5779
# mahmood munim
# 5780
# tarchumas "tadas" murnikas
# 5781
# albert muylle
# 5782
# mustapha najjari
# 5783
# edward newell
# 5784
# ng thnh lim
# 5785
# nguyn hw thoa
# 5786
# nguyn vn khoi
# 5787
# nguyn vn nhieu
# 5788
# stamatios nikolopoulos
# 5789
# emmanuel nkurunziza
# 5790
# rohinton noble
# 5791
# david roddis noon
# 5792
# j. norman
# 5793
# arnold ntzli
# 5794
# ji nouza
# 5795
# ahmed omar
# 5796
# hamid oraibi
# 5797
# william anthony ormston
# 5798
# john brendan o'sullivan
# 5799
# george owen
# 5800
# roberts ozols
# 5801
# georgios paraskevopoulos
# 5802
# alphonse parfondry
# 5803
# battista parini
# 5804
# miguel ngel passi
# 5805
# karel pechan
# 5806
# juan prez
# 5807
# ceferino peron
# 5808
# ioannis petritsis
# 5809
# pichard
# 5810
# eric c. pilcher
# 5811
# pilton
# 5812
# luis poggi cebrero
# 5813
# julio emilio polet
# 5814
# zenons popovs
# 5815
# a. porcher
# 5816
# pouget
# 5817
# andr poulain
# 5818
# homi powri
# 5819
# josef prochzka
# 5820
# lance i. pugh
# 5821
# konrad puhrer
# 5822
# nicolas "nic" rausch
# 5823
# lucien renard
# 5824
# antonio restelli
# 5825
# ret chhon
# 5826
# ahmed rhail
# 5827
# domingo rivas
# 5828
# glen robbins
# 5829
# david cairns robertson
# 5830
# carlos rocuant lpez
# 5831
# francisco rodrguez
# 5832
# gabino rodrguez rodela
# 5833
# a. roger
# 5834
# boris nikolayevich romanov
# 5835
# adolfo romero quiones
# 5836
# paul rosso
# 5837
# honorio rua betancourt
# 5838
# ruez
# 5839
# milcho dimov rusev
# 5840
# arthur rushen
# 5841
# mihly rusovszky
# 5842
# saignier
# 5843
# piloo sarkari
# 5844
# l. saunire
# 5845
# boris savostin
# 5846
# naji sayed
# 5847
# julius schaefer
# 5848
# sebestyn schmidt
# 5849
# pierre seginaud
# 5850
# khalid shebani
# 5851
# frank shore
# 5852
# frederick william "fred" short
# 5853
# josef dlo
# 5854
# william r. "bill" smith
# 5855
# jorge sobrevila
# 5856
# josip olar
# 5857
# manuel solis archundia
# 5858
# patrick spencer
# 5859
# james e. "jack" standen
# 5860
# ferenc steiner (homoky)
# 5861
# m. steitz
# 5862
# borislav stoyanov
# 5863
# giacomo stratta
# 5864
# hans studer
# 5865
# george f. summers
# 5866
# bla szekeres
# 5867
# william taylor
# 5868
# maurice terrier
# 5869
# daniel tesfaye
# 5870
# mesfen tesfaye
# 5871
# marc texier
# 5872
# paul texier
# 5873
# thomann
# 5874
# trn gia thu
# 5875
# andr trantoul
# 5876
# john "jack" trickey
# 5877
# trung trung l
# 5878
# a. tryfiatis-trypiapis
# 5879
# lev mironovich tsipursky
# 5880
# george turner
# 5881
# konstantinos tzortzakis
# 5882
# ferenc uhereczky
# 5883
# fridrihs uksti
# 5884
# rafael vaca vldez
# 5885
# jean van benthem
# 5886
# emile van de velde
# 5887
# charles van doorselaer
# 5888
# floris t. venter
# 5889
# andr vercruysse
# 5890
# alexandros verdesopoulos
# 5891
# john slaats verhoeven
# 5892
# prospre "romeo" verschelden
# 5893
# frans verschueren
# 5894
# vianzino
# 5895
# alejandro vidal arellano
# 5896
# jaime villegas
# 5897
# richard villepontoux
# 5898
# juozas vilpiauskas
# 5899
# vincent
# 5900
# james r. walker
# 5901
# arlee wararong
# 5902
# george watson
# 5903
# gottfried weilenmann
# 5904
# joseph welzenbacher
# 5905
# douard wick
# 5906
# andrew "andy" wilson
# 5907
# joseph p. "john" woodcock
# 5908
# alois wutte
# 5909
# yi yuong
# 5910
# harry r. l. young
# 5911
# artrs zeiberli
# 5912
# aleksandar zori
# 5913
# mohamed abdel khalek allam
# 5914
# d. argalias
# 5915
# jeannette aubert (-pinci)
# 5916
# alexandru adrian "alex" bagiu
# charles darley miller
# 6466
# george arthur miller
# 6467
# john carter "jack" montgomery
# 6468
# julio mller lujn
# 6469
# antonio nava castillo
# 6470
# william brookes "guillermo" naylor
# 6471
# juan diego "jack" nelson y duggan
# 6472
# patteson womersley nickalls
# 6473
# percy philip o'reilly
# 6474
# enrique padilla
# 6475
# jean andr hubert pastr
# 6476
# alberto ramos sesma
# 6477
# maurice auguste raoul-duval
# 6478
# alfred "toby" rawlinson
# 6479
# robert miles sloman reincke
# 6480
# fred roe, sr.
# 6481
# auston morgan rotheram
# 6482
# leopoldo sanz de la maza gutirrez-solana y gmez de la puente
# 6483
# imre szentply
# 6484
# rodman lewis "rod" wanamaker
# 6485
# herbert haydon wilson
# 6486
# percival kinnear wise
# 6487
# john "jack" wodehouse
# 6488
# john jacob astor
# 6489
# henry brougham
# 6490
# cecil le cronier browning
# 6491
# edmond william bury
# 6492
# evan baillie noel
# 6493
# vane hungerford pennell
# 6494
# edwin anthony biedermann (-best)
# 6495
# william marshall cazalet
# 6496
# jay gould, ii
# 6497
# neville stephen bulwer-lytton
# 6498
# eustace hamilton miles
# 6499
# arthur page
# 6500
# arnold nottage palmer
# 6501
# charles edward sands
# 6502
# charles edmund tatham
# 6503

# %% [markdown]
# Drop the nan_df raws from main Dataframe

# %%
indexs = nan_df.index.tolist()
df = df.drop(indexs)
df
# Out:
#          Age       City                                       Event  \
# 0       24.0  barcelona                 basketball men's basketball
# 167     19.0    beijing               basketball women's basketball
# 250     31.0   helsinki                 basketball men's basketball
# 264     29.0     sydney                 basketball men's basketball
# 346     25.0     munich                 basketball men's basketball
# ...      ...        ...                                         ...
# 239604  26.0     london  motorboating mixed b-class (under 60 feet)
# 239605  26.0     london                  motorboating mixed c-class
# 239707  46.0     london           motorboating mixed a-class (open)
# 259371  29.0     london           motorboating mixed a-class (open)
# 263253  31.0     london                  motorboating mixed c-class
#
#               Games  Height        ID Medal  NOC  \
# 0       1992 summer   180.0       1.0   NaN  chn
# 167     2008 summer   185.0      69.0   NaN  esp
# 250     1952 summer   191.0     124.0   NaN  egy
# 264     2000 summer   195.0     136.0   NaN  ita
# 346     1972 summer   189.0     192.0   NaN  egy
# ...             ...     ...       ...   ...  ...
# 239604  1908 summer   181.0  120083.0  gold  gbr
# 239605  1908 summer   181.0  120083.0  gold  gbr
# 239707  1908 summer   181.0  120129.0  gold  fra
# 259371  1908 summer   181.0  129853.0   NaN  gbr
# 263253  1908 summer   181.0  131731.0   NaN  gbr
#
#                                       Name  Season Sex         Sport  \
# 0                                a dijiang  summer   m    basketball
# 167                      tamara abalde daz  summer   f    basketball
# 250                  youssef mohamed abbas  summer   m    basketball
# 264                       alessandro abbio  summer   m    basketball
# 346     ahmed el-sayed abdel hamid mobarak  summer   m    basketball
# ...                                    ...     ...  ..           ...
# 239604            isaac thomas thornycroft  summer   m  motorboating
# 239605            isaac thomas thornycroft  summer   m  motorboating
# 239707     ernest blakelock "mile" thubron  summer   m  motorboating
# 259371       hugh richard arthur grosvenor  summer   m  motorboating
# 263253               joseph warwick wright  summer   m  motorboating
#
#                        Team  Weight    Year
# 0                     china    80.0  1992.0
# 167                   spain    72.0  2008.0
# 250                   egypt    85.0  1952.0
# 264                   italy    85.0  2000.0
# 346                   egypt    85.0  1972.0
# ...                     ...     ...     ...
# 239604            gyrinus-1    77.0  1908.0
# 239605            gyrinus-1    77.0  1908.0
# 239707              camille    77.0  1908.0
# 259371  wolseley-siddeley-1    77.0  1908.0
# 263253            sea dog-2    77.0  1908.0
#
# [254974 rows x 15 columns]

# %% [markdown]
# Create the cleaned_df that represents the clean version of data frame

# %%
cleaned_df =pd.concat([df, new_df], axis=0)
cleaned_df.drop_duplicates(inplace=True)

# %%
cleaned_df
# Out:
#        Age       City                          Event        Games  Height  \
# 0     24.0  barcelona    basketball men's basketball  1992 summer   180.0
# 167   19.0    beijing  basketball women's basketball  2008 summer   185.0
# 250   31.0   helsinki    basketball men's basketball  1952 summer   191.0
# 264   29.0     sydney    basketball men's basketball  2000 summer   195.0
# 346   25.0     munich    basketball men's basketball  1972 summer   189.0
# ...    ...        ...                            ...          ...     ...
# 9761  39.0     london     jeu de paume men's singles  1908 summer   178.0
# 9762  32.0     london     jeu de paume men's singles  1908 summer   178.0
# 9763  21.0     london     jeu de paume men's singles  1908 summer   178.0
# 9764  42.0     london     jeu de paume men's singles  1908 summer   181.0
# 9765  43.0     london     jeu de paume men's singles  1908 summer   178.0
#
#             ID   Medal  NOC                                Name  Season Sex  \
# 0          1.0     NaN  chn                           a dijiang  summer   m
# 167       69.0     NaN  esp                   tamara abalde daz  summer   f
# 250      124.0     NaN  egy               youssef mohamed abbas  summer   m
# 264      136.0     NaN  ita                    alessandro abbio  summer   m
# 346      192.0     NaN  egy  ahmed el-sayed abdel hamid mobarak  summer   m
# ...        ...     ...  ...                                 ...     ...  ..
# 9761   79794.0  silver  gbr              eustace hamilton miles  summer   m
# 9762   90545.0     NaN  gbr                         arthur page  summer   m
# 9763   90836.0     NaN  gbr               arnold nottage palmer  summer   m
# 9764  105390.0     NaN  usa                charles edward sands  summer   m
# 9765  118745.0     NaN  gbr               charles edmund tatham  summer   m
#
#              Sport           Team  Weight    Year
# 0       basketball          china    80.0  1992.0
# 167     basketball          spain    72.0  2008.0
# 250     basketball          egypt    85.0  1952.0
# 264     basketball          italy    85.0  2000.0
# 346     basketball          egypt    85.0  1972.0
# ...            ...            ...     ...     ...
# 9761  jeu de paume  great britain    74.0  1908.0
# 9762  jeu de paume  great britain    74.0  1908.0
# 9763  jeu de paume  great britain    74.0  1908.0
# 9764  jeu de paume  united states    74.0  1908.0
# 9765  jeu de paume  great britain    74.0  1908.0
#
# [263246 rows x 15 columns]

# %% [markdown]
# Reindexing cleaned_df

# %%
cleaned_df = cleaned_df.reset_index()
cleaned_df = cleaned_df.drop(columns=["index"])
cleaned_df
# Out:
#          Age       City                          Event        Games  Height  \
# 0       24.0  barcelona    basketball men's basketball  1992 summer   180.0
# 1       19.0    beijing  basketball women's basketball  2008 summer   185.0
# 2       31.0   helsinki    basketball men's basketball  1952 summer   191.0
# 3       29.0     sydney    basketball men's basketball  2000 summer   195.0
# 4       25.0     munich    basketball men's basketball  1972 summer   189.0
# ...      ...        ...                            ...          ...     ...
# 263241  39.0     london     jeu de paume men's singles  1908 summer   178.0
# 263242  32.0     london     jeu de paume men's singles  1908 summer   178.0
# 263243  21.0     london     jeu de paume men's singles  1908 summer   178.0
# 263244  42.0     london     jeu de paume men's singles  1908 summer   181.0
# 263245  43.0     london     jeu de paume men's singles  1908 summer   178.0
#
#               ID   Medal  NOC                                Name  Season Sex  \
# 0            1.0     NaN  chn                           a dijiang  summer   m
# 1           69.0     NaN  esp                   tamara abalde daz  summer   f
# 2          124.0     NaN  egy               youssef mohamed abbas  summer   m
# 3          136.0     NaN  ita                    alessandro abbio  summer   m
# 4          192.0     NaN  egy  ahmed el-sayed abdel hamid mobarak  summer   m
# ...          ...     ...  ...                                 ...     ...  ..
# 263241   79794.0  silver  gbr              eustace hamilton miles  summer   m
# 263242   90545.0     NaN  gbr                         arthur page  summer   m
# 263243   90836.0     NaN  gbr               arnold nottage palmer  summer   m
# 263244  105390.0     NaN  usa                charles edward sands  summer   m
# 263245  118745.0     NaN  gbr               charles edmund tatham  summer   m
#
#                Sport           Team  Weight    Year
# 0         basketball          china    80.0  1992.0
# 1         basketball          spain    72.0  2008.0
# 2         basketball          egypt    85.0  1952.0
# 3         basketball          italy    85.0  2000.0
# 4         basketball          egypt    85.0  1972.0
# ...              ...            ...     ...     ...
# 263241  jeu de paume  great britain    74.0  1908.0
# 263242  jeu de paume  great britain    74.0  1908.0
# 263243  jeu de paume  great britain    74.0  1908.0
# 263244  jeu de paume  united states    74.0  1908.0
# 263245  jeu de paume  great britain    74.0  1908.0
#
# [263246 rows x 15 columns]

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263246 entries, 0 to 263245
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Age     263246 non-null  float64
#  1   City    263246 non-null  object
#  2   Event   263246 non-null  object
#  3   Games   263246 non-null  object
#  4   Height  263246 non-null  float64
#  5   ID      263246 non-null  float64
#  6   Medal   38731 non-null   object
#  7   NOC     263246 non-null  object
#  8   Name    263246 non-null  object
#  9   Season  263246 non-null  object
#  10  Sex     263246 non-null  object
#  11  Sport   263246 non-null  object
#  12  Team    263246 non-null  object
#  13  Weight  263246 non-null  float64
#  14  Year    263246 non-null  float64
# dtypes: float64(5), object(10)
# memory usage: 30.1+ MB

# %%
cleaned_df.describe()
# Out:
#                  Age         Height             ID         Weight         Year
# count  263246.000000  263246.000000  263246.000000  263246.000000  263246.0000
# mean       25.315731     175.072841   68248.354076      70.119236    1978.5681
# std         5.879985       9.525086   39033.233081      12.177562      29.7128
# min        10.000000     137.000000       1.000000      31.000000    1896.0000
# 25%        21.000000     169.000000   34630.000000      62.000000    1960.0000
# 50%        24.000000     175.000000   68209.000000      70.000000    1988.0000
# 75%        28.000000     181.000000  102091.000000      77.000000    2002.0000
# max        77.000000     220.000000  135571.000000     135.000000    2016.0000

# %% [markdown]
# We note that we drop just 3% from the data, which is acceptable.

# %% [markdown]
# Save it as CSV file

# %%
cleaned_df.to_csv('filterd_athlete_events.csv')
